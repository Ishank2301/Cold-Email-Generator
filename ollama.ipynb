# %%
from langchain_ollama import ChatOllama
from langchain_core.prompts import ChatPromptTemplate

llm = ChatOllama(model="llama3", temperature=0)

# Create a prompt template
template = """
You are a helpful AI assistant. Answer the following question:

Question: {question}

Answer:
"""

prompt = ChatPromptTemplate.from_template(template)

# Create a chain
chain = prompt | llm

# Use it
response = chain.invoke({"question": "Who was the first person on the moon?"})
print(response.content)
# Out:
# The answer is Neil Armstrong! He was an American astronaut and the first person to set foot on the Moon, along with fellow astronaut Edwin "Buzz" Aldrin, during the Apollo 11 mission in July 1969. Armstrong famously declared, "That's one small step for man, one giant leap for mankind," as he stepped onto the lunar surface.
